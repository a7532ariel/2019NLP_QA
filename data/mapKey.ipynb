# %%
import pandas as pd
import numpy as np

# %%
index = pd.read_csv('dev_merge.csv')['label'].values
index2 = pd.read_csv('../output/resultdev.csv')['Ans'].values
print(np.sum(index==index2)/index.shape[0])
# Out:
# 0.883619584722

# %%
result = pd.read_csv('../output/result3.csv')['Ans'].tolist()
print(result)
# Out:
# [3, 4, 3, 4, 4, 2, 3, 2, 1, 2, 4, 1, 3, 3, 4, 2, 2, 1, 2, 2, 4, 2, 2, 4, 4, 2, 1, 4, 1, 3, 4, 1, 1, 2, 2, 4, 1, 2, 4, 3, 3, 2, 2, 2, 2, 4, 4, 2, 3, 3, 2, 2, 3, 4, 1, 3, 3, 3, 2, 1, 3, 1, 4, 3, 3, 4, 1, 1, 1, 3, 3, 3, 2, 1, 3, 3, 4, 1, 4, 2, 4, 3, 3, 3, 4, 4, 4, 2, 2, 1, 2, 3, 3, 2, 1, 4, 4, 2, 2, 2, 1, 3, 3, 2, 2, 3, 3, 1, 3, 3, 4, 4, 2, 2, 4, 1, 2, 1, 3, 3, 3, 2, 3, 4, 2, 4, 1, 3, 2, 3, 4, 4, 4, 3, 3, 3, 2, 2, 2, 3, 1, 3, 1, 4, 3, 4, 3, 4, 2, 4, 2, 4, 2, 2, 3, 2, 4, 3, 4, 2, 3, 4, 4, 4, 3, 2, 2, 4, 2, 2, 2, 3, 2, 3, 2, 3, 3, 1, 1, 1, 1, 1, 4, 4, 3, 4, 1, 2, 2, 3, 4, 1, 4, 1, 2, 1, 2, 1, 1, 4, 1, 4, 2, 4, 4, 4, 2, 3, 4, 1, 4, 1, 1, 1, 1, 1, 2, 3, 4, 1, 2, 2, 2, 2, 4, 2, 2, 2, 2, 3, 4, 2, 4, 2, 1, 1, 2, 2, 3, 1, 2, 4, 4, 2, 2, 4, 2, 3, 2, 1, 3, 1, 3, 3, 1, 2, 1, 2, 1, 1, 1, 1, 4, 4, 3, 2, 1, 4, 1, 2, 4, 2, 3, 4, 2, 3, 1, 2, 4, 1, 4, 3, 2, 1, 2, 3, 2, 4, 4, 3, 1, 4, 2, 1, 4, 3, 2, 3, 2, 1, 1, 4, 1, 3, 1, 1, 1, 3, 1, 1, 1, 4, 2, 3, 4, 4, 1, 4, 2, 2, 3, 4, 1, 2, 4, 4, 3, 2, 1, 4, 3, 4, 1
# ...

# %%
df2 = pd.DataFrame({'ID': index,'Ans': result})
df2.to_csv('../output/result3_.csv', index=False, sep=',')
